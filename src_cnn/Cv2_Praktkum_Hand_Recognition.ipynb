jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1588.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1589.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok159.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1590.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1591.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1592.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1593.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1594.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1595.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1596.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1597.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1598.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1599.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok16.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok160.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1600.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1601.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1602.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1603.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1604.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1605.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1606.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1607.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1608.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1609.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok161.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1610.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1611.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1612.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1613.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1614.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1615.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1616.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1617.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1618.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1619.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok162.jpg
#   inflating: ./hand-gesture-recog-dataset/data/ok/ok1620.jpg
# ...
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup804.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup805.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup806.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup807.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup808.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup809.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup81.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup810.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup811.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup812.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup813.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup814.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup815.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup816.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup817.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup818.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup819.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup82.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup820.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup821.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup822.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup823.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup824.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup825.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup826.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup827.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup828.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup829.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup83.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup830.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup831.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup832.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup833.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup834.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup835.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup836.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup837.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup838.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup839.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup84.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup840.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup841.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup842.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup843.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup844.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup845.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup846.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup847.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup848.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup849.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup85.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup850.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup851.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup852.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup853.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup854.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup855.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup856.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup857.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup858.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup859.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup86.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup860.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup861.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup862.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup863.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup864.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup865.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup866.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup867.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup868.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup869.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup87.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup870.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup871.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup872.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup873.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup874.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup875.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup876.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup877.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup878.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup879.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup88.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup880.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup881.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup882.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup883.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup884.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup885.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup886.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup887.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup888.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup889.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup89.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup890.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup891.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup892.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup893.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup894.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup895.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup896.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup897.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup898.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup899.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup9.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup90.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup900.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup901.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup902.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup903.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup904.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup905.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup906.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup907.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup908.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup909.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup91.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup910.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup911.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup912.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup913.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup914.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup915.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup916.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup917.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup918.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup919.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup92.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup920.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup921.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup922.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup923.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup924.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup925.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup926.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup927.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup928.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup929.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup93.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup930.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup931.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup932.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup933.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup934.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup935.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup936.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup937.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup938.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup939.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup94.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup940.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup941.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup942.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup943.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup944.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup945.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup946.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup947.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup948.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup949.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup95.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup950.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup951.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup952.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup953.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup954.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup955.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup956.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup957.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup958.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup959.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup96.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup960.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup961.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup962.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup963.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup964.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup965.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup966.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup967.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup968.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup969.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup97.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup970.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup971.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup972.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup973.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup974.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup975.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup976.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup977.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup978.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup979.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup98.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup980.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup981.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup982.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup983.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup984.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup985.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup986.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup987.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup988.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup989.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup99.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup990.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup991.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup992.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup993.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup994.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup995.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup996.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup997.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup998.jpg
#   inflating: ./hand-gesture-recog-dataset/data/thumbsup/thumbsup999.jpg

# %% [markdown]
# ## 1.2 Import

# %%
# import librarys
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import numpy as np
import cv2
import os
import logging
import pandas as pd
import random
from IPython.display import SVG
import math
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# import necessary tensorflow librarys
from tensorflow.keras import Input
from tensorflow.data import Dataset
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.utils import plot_model, model_to_dot
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, \
ZeroPadding2D, RandomRotation, RandomCrop, RandomZoom, BatchNormalization, Rescaling
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16

# %% [markdown]
# # 3. Data Pre-Processing

# %% [markdown]
# ## 3.1 Load and Split Data

# %%
# configuration
VAL_SIZE = 0.2
TEST_SIZE = 0.2
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 16
NUM_CHANNELS = 1 # NUM_CHANNELS 1 for "grayscale"
DATA_DIR = './hand-gesture-recog-dataset/data'

# %%
# load the training data set as gray images
train_ds = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=VAL_SIZE+TEST_SIZE,
  label_mode="categorical",
  subset="training",
  color_mode="grayscale",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)

# load validation data set
val_test_ds = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=VAL_SIZE+TEST_SIZE,
  label_mode="categorical",
  subset="validation",
  color_mode="grayscale",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 10321 files belonging to 6 classes.
# Using 6193 files for training.
# Found 10321 files belonging to 6 classes.
# Using 4128 files for validation.

# %%
# split validation data set in val_ds and test_ds
val_batches = len(val_test_ds)
test_ds = val_test_ds.take(val_batches // 2)
val_ds = val_test_ds.skip(val_batches // 2)

# count number of batches in training, validation and test dataset
print(f"""The dataset is distributed in :
  - {len(train_ds)} Batches for training
  - {len(test_ds)} Batches for testing
  - {len(val_ds)} Batches for validation with each {BATCH_SIZE} images per Batch
      """)
# Out:
# The dataset is distributed in :
#   - 388 Batches for training
#   - 129 Batches for testing
#   - 129 Batches for validation with each 16 images per Batch

# %% [markdown]
# ## 3.2 Data Exploring

# %%
# store class names
CLASS_NAMES = train_ds.class_names
CLASS_NAMES
# Out:
# ['blank', 'fist', 'five', 'ok', 'thumbsdown', 'thumbsup']

# %%
# read original data with cv2
total_images = []
total_labels = []
set_of_shapes = set()
set_of_formats = set()
for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.endswith(".jpg"):
            path = os.path.join(root, file)
            image = cv2.imread(path, cv2.IMREAD_GRAYSCALE) # Load the image here
            if image is not None: # Check if image loaded successfully
                total_images.append(path)
                #Extract the name of class from the root
                total_labels.append(root.split(os.path.sep)[-1])
                set_of_shapes.add(image.shape) # Add shape of the image

# print the maximum and minimum shape object
if set_of_shapes: # Check if set_of_shapes is not empty
    print(f"""Smallest detected shape: {list(sorted(set_of_shapes))[0]}
    Largest detected shape: {list(sorted(set_of_shapes))[-1]}""")
else:
    print("No image shapes were recorded.")
# Out:
# Smallest detected shape: (50, 50)
#     Largest detected shape: (215, 240)

# %%
# set_of_shapes = set()
# set_of_formats = set()
# for path in total_images:
#   image_temp = cv2.imread(path)
#   image_shape_temp = image_temp.shape
#   if len(set_of_shapes) < 20:
#     set_of_shapes.add(image_shape_temp)
#   if len(set_of_formats) < 100:
#     set_of_formats.add(image_shape_temp[0]/image_shape_temp[1])
#   else:
#     break

# # print the smallest and largest aspect ratio
# print(f"""Smallest aspect ratio: {min(set_of_formats)}
# Largest aspect ratio: {max(set_of_formats)}""")

# %% [markdown]
# ## 3.3 Data Plotting

# %%
# count number of items in each class
def count_images_in_dataset(dataset: Dataset, print_items: bool = False, dataset_description: str = "Training"):
  ds_class_counts = []
  for images, labels in dataset:
    class_counts = tf.reduce_sum(labels, axis=0)
    ds_class_counts.append(class_counts)
  ds_class_counts = tf.reduce_sum(ds_class_counts, axis=0)
  # Print the number of images in each class for the current dataset optional
  if print_items:
    for i, class_name in enumerate(CLASS_NAMES):
        print(f"{dataset_description} - Class '{class_name}': {int(ds_class_counts[i])}")
  return ds_class_counts

# %%
# store occurences of each class in the train, test & val datasets in a dict
dataset_number_of_occurences = {}
for dataset, print_items, dataset_description in [[train_ds, False, "Training"], [test_ds, False, "Test"], \
 [val_ds, False, "Validation"]]:
 dataset_number_of_occurences[dataset_description] = count_images_in_dataset(dataset, print_items, dataset_description)

# %%
# aggregate occurences over the different datasets, to see the class distribution over the whole dataset
all_classes_count = {}
for counter, key in enumerate(CLASS_NAMES):
  all_classes_count[key] = dataset_number_of_occurences['Training'][counter] + dataset_number_of_occurences['Test'][counter] + \
  dataset_number_of_occurences['Validation'][counter]

# %%
# plot data frequency for the whole dataset
plt.figure(figsize=(20,5))
data = pd.DataFrame(data = {'class_name': all_classes_count.keys(), 'sum of entries': all_classes_count.values()})
data["sum of entries"] = data["sum of entries"].astype("int32")
ax = sns.barplot(data = data, x= "class_name", y="sum of entries")
ax.set(xlabel = "Classes", ylabel = "Sum of entries")
for p in ax.patches:
    ax.annotate(str(p.get_height()), xy=(p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')
plt.title(f"Distribution of each class")
plt.show()

# %%
# plot data frequency by set
df_counts_by_classes: pd.DataFrame = pd.DataFrame(dataset_number_of_occurences, index=CLASS_NAMES)
fig, axs = plt.subplots(figsize=(20,5))
axs.set_title(f"Distribution of each class split by the different datasets")
axs.set(xlabel = "Classes", ylabel = "Sum of entries")
df_counts_by_classes.plot(kind='bar', stacked=True, ax=axs)
fig.show()

# %%
# Visualisation of the distribution in each class
grid_size = (3, 3)
plt.figure(figsize=(10, 10))
for i, subdir in enumerate(CLASS_NAMES[:6]):
    subdir_path = os.path.join(DATA_DIR, subdir)
    files = [f for f in os.listdir(subdir_path) if os.path.isfile(os.path.join(subdir_path, f))]

    if files:
        # The first image in the subdirectory
        first_image_path = os.path.join(subdir_path, files[0])
        image = cv2.imread(first_image_path)

        if image is not None:
            image = cv2.resize(image, (100, 120))
            plt.subplot(grid_size[0], grid_size[1], i + 1)
            plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            plt.title(f"{subdir}")
            plt.axis('off')
        else:
            print(f"Fehler: Das Bild unter dem Pfad '{first_image_path}' konnte nicht gelesen werden.")
    else:
        print(f"Fehler: Keine Dateien im Verzeichnis '{subdir_path}' gefunden.")
plt.show()

# %%
# callback function to update the learning rate every epoch to find the optimal learning rate
# lr_schedule = tf.keras.callbacks.LearningRateScheduler(
#     lambda epoch: 1e-8 * 10**(epoch / 20))

# define the optimizer
optimizer_lr_finder = tf.keras.optimizers.Adam(learning_rate=1e-8)
optimizer_training = tf.keras.optimizers.Adam(learning_rate=1e-5)

# Training parameter
EPOCHS = 10
#EARLY_STOPPING_PATIENCE = math.sqrt(EPOCHS)
num_classes = len(CLASS_NAMES)

# setup early stopping
# early_stopping = tf.keras.callbacks.EarlyStopping(patience=EARLY_STOPPING_PATIENCE,
#                                                   verbose=2,
#                                                   restore_best_weights=True)

# %% [markdown]
# # 4. Modeltraining

# %%
# model
def cnn_model():
  model = Sequential()

  # first conv layer
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, NUM_CHANNELS)))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  # second conv layer
  model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  # flatten and put a fully connected layer
  model.add(Flatten())
  model.add(Dense(128, activation='relu')) # fully connected
  model.add(Dropout(0.5))

  # softmax layer
  model.add(Dense(6, activation='softmax'))

  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

model = cnn_model()
history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)
score = model.evaluate(test_ds, verbose=0)
print("Accuracy:" + str(score[1]))
print('The error is: %.2f%%' % (100 - score[1] * 100))
model.save('gesture_recognition_cnn.h5')
# Out:
# Epoch 1/10
# 388/388 - 29s - loss: 2.6196 - accuracy: 0.8716 - val_loss: 0.1979 - val_accuracy: 0.9859 - 29s/epoch - 75ms/step
# Epoch 2/10
# 388/388 - 23s - loss: 0.4685 - accuracy: 0.9359 - val_loss: 0.0753 - val_accuracy: 0.9893 - 23s/epoch - 59ms/step
# Epoch 3/10
# 388/388 - 25s - loss: 0.3377 - accuracy: 0.9522 - val_loss: 0.1000 - val_accuracy: 0.9893 - 25s/epoch - 64ms/step
# Epoch 4/10
# 388/388 - 26s - loss: 0.3784 - accuracy: 0.9591 - val_loss: 0.2011 - val_accuracy: 0.9908 - 26s/epoch - 66ms/step
# Epoch 5/10
# 388/388 - 26s - loss: 0.5066 - accuracy: 0.9611 - val_loss: 0.0752 - val_accuracy: 0.9956 - 26s/epoch - 66ms/step
# Epoch 6/10
# 388/388 - 23s - loss: 0.2642 - accuracy: 0.9696 - val_loss: 0.0526 - val_accuracy: 0.9966 - 23s/epoch - 60ms/step
# Epoch 7/10
# 388/388 - 23s - loss: 0.1827 - accuracy: 0.9790 - val_loss: 0.0112 - val_accuracy: 0.9981 - 23s/epoch - 58ms/step
# Epoch 8/10
# 388/388 - 23s - loss: 0.2661 - accuracy: 0.9772 - val_loss: 0.0065 - val_accuracy: 0.9976 - 23s/epoch - 59ms/step
# Epoch 9/10
# 388/388 - 24s - loss: 0.2267 - accuracy: 0.9821 - val_loss: 0.0062 - val_accuracy: 0.9985 - 24s/epoch - 61ms/step
# Epoch 10/10
# 388/388 - 26s - loss: 0.3077 - accuracy: 0.9829 - val_loss: 0.0081 - val_accuracy: 0.9990 - 26s/epoch - 68ms/step
# Accuracy:0.9975775480270386
# The error is: 0.24%
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 5. Evaluation

# %%
def plot_history(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(len(acc))

  plt.figure(figsize=(12, 6))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()

# %%
plot_history(history)

# %%
# plt.plot(history.history['accuracy'], label='accuracy')
# plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.ylim([0.5, 1])
# plt.titel("Training and Valiadation Accuracy")
# plt.legend(loc='lower right')

# %%
test_loss, test_acc = model.evaluate(test_ds, verbose=2)
print("Accuracy on Test Data", test_acc)
# Out:
# 129/129 - 1s - loss: 0.0206 - accuracy: 0.9976 - 1s/epoch - 10ms/step
# Accuracy on Test Data 0.9975775480270386

# %%
# iterate over the test dataset and store predictions
predictions = np.array([])
labels =  np.array([])
for x, y in test_ds:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x), axis=1)])
  labels = np.concatenate([labels, np.argmax(y.numpy(), axis=-1)])

model.evaluate(test_ds)
print(classification_report(labels, predictions))

conf_matrix = confusion_matrix(labels, predictions)
# Display confusion matrix
# Change figure size and increase dpi for better resolution
plt.figure(figsize=(8,6), dpi=100)

# Scale up the size of all text
sns.set(font_scale = 1.1)

# Plot Confusion Matrix using Seaborn heatmap
ax = sns.heatmap(conf_matrix, annot=True, fmt='d')

# set x-axis label and ticks.
ax.set_xlabel("Predicted Diagnosis", fontsize=14, labelpad=20)
ax.xaxis.set_ticklabels(CLASS_NAMES, rotation=90)

# set y-axis label and ticks
ax.set_ylabel("Actual Diagnosis", fontsize=14, labelpad=20)
ax.yaxis.set_ticklabels(CLASS_NAMES, rotation=0)

# set plot title
ax.set_title("Confusion Matrix for the Document classification", fontsize=14, pad=20)

plt.show()
# Out:
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0206 - accuracy: 0.9976
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       302
#          1.0       1.00      1.00      1.00       323
#          2.0       1.00      0.99      1.00       418
#          3.0       0.99      1.00      1.00       348
#          4.0       0.99      1.00      1.00       323
#          5.0       1.00      0.99      1.00       350
#
#     accuracy                           1.00      2064
#    macro avg       1.00      1.00      1.00      2064
# weighted avg       1.00      1.00      1.00      2064

# %%
# Anzahl der Bilder im Dataset
dataset_size = sum(1 for _ in test_ds)

shuffled_ds = test_ds.shuffle(buffer_size=dataset_size)

# Iteriere über das Dataset, um ein zufälliges Bild und die zugehörigen Labels zu bekommen
for images, labels in shuffled_ds.take(1):  # Hier nimmst du nur das erste Element (Batch) aus dem durchmischten Dataset
    # Nehme das erste Bild aus dem Batch
    image = images[0:1]  # Hier nimmst du das erste Bild aus dem Batch
    true_labels = labels[0]  # Hier nimmst du die zugehörigen Labels zum ersten Bild

# Konvertiere die true_labels in den Klassenindex oder -label, je nach Bedarf
true_class_index = np.argmax(true_labels)
true_label = CLASS_NAMES[true_class_index]

# Plot des Bildes
plt.figure(figsize=(6, 6))
plt.imshow(np.squeeze(image), cmap='gray')  # Hier wird das Bild geplottet (ohne die Batch-Dimension)
plt.title(f'Wahre Klasse: {true_label}')
plt.axis('off')
plt.show()

# %%
# Iteriere über das Dataset, um das erste Bild und die zugehörigen Labels zu bekommen
for images, labels in test_ds.take(1):  # Hier nimmst du nur das erste Element (Batch) aus dem Dataset
    # Nehme das erste Bild aus dem Batch
    image = images[0:1]  # Hier nimmst du das erste Bild aus dem Batch
    true_labels = labels[0]  # Hier nimmst du die zugehörigen Labels zum ersten Bild

# Konvertiere die true_labels in den Klassenindex oder -label, je nach Bedarf
true_class_index = np.argmax(true_labels)
classes = ['blank', 'fist', 'five', 'ok', 'thumbsdown', 'thumbsup']
true_label = CLASS_NAMES[true_class_index]

# Plot des Bildes
plt.figure(figsize=(6, 6))
plt.imshow(np.squeeze(image), cmap='gray')  # Hier wird das Bild geplottet (ohne den Batch-Dimension)
plt.title(f'Wahre Klasse: {true_label}')
plt.axis('off')
plt.show()

# %%
# model = load_model('/content/gesture_recognition_cnn.h5')

# image = cv2.imread("/content/roi_30.png")

# # Preprocess the image to match the model's expected input
# image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
# image = cv2.resize(image, (224, 224))  # Resize to 224x224
# image = np.expand_dims(image, axis=0)  # Add batch dimension
# image = np.expand_dims(image, axis=-1) # Add channel dimension

# # Predict the hand gesture
# prediction = model.predict(image)
# label = classes[np.argmax(prediction)]

# print(f"Prediction for the image: {label}")

# %%
# import keras
# from keras.datasets import mnist
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Flatten, BatchNormalization
# from keras.layers import Activation, Dropout
# from keras.layers import Conv2D, MaxPooling2D
# from keras import backend as K
# from keras.optimizers import Adam

# import os
# import glob

# import cv2
# import matplotlib.pyplot as plt

# %%
# # Visualisation of the distribution in each class
# grid_size = (3, 3)
# plt.figure(figsize=(10, 10))
# for i, subdir in enumerate(labels[:6]):
#     subdir_path = os.path.join(DATASET_PATH, subdir)
#     files = [f for f in os.listdir(subdir_path) if os.path.isfile(os.path.join(subdir_path, f))]

#     if files:
#         # The first image in the subdirectory
#         first_image_path = os.path.join(subdir_path, files[0])
#         image = cv2.imread(first_image_path)

#         if image is not None:
#             image = cv2.resize(image, (100, 120))
#             plt.subplot(grid_size[0], grid_size[1], i + 1)
#             plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#             plt.title(f"{subdir}")
#             plt.axis('off')
#         else:
#             print(f"Fehler: Das Bild unter dem Pfad '{first_image_path}' konnte nicht gelesen werden.")
#     else:
#         print(f"Fehler: Keine Dateien im Verzeichnis '{subdir_path}' gefunden.")
# plt.show()

# %%
# # model
# model = Sequential()

# # first conv layer
# # input shape = (img_rows, img_cols, 1)
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(100,120, 1)))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# # second conv layer
# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# # flatten and put a fully connected layer
# model.add(Flatten())
# model.add(Dense(128, activation='relu')) # fully connected
# model.add(Dropout(0.5))

# # softmax layer
# model.add(Dense(6, activation='softmax'))

# # model summary
# optimiser = Adam()
# model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# model.summary()

# %%
# # Loading the Dataset
# DATASET_PATH = './hand-gesture-recog-dataset/data'

# dataset_path = os.path.join(DATASET_PATH, '*')
# dataset_path = glob.glob(dataset_path)
# dataset_path

# %%
# # List of gestures
# labels = [d for d in os.listdir(DATASET_PATH) if os.path.isdir(os.path.join(DATASET_PATH, d))]
# labels

# %%
# # Pre-Processing
# def preprocessing(img):
#   image = cv2.imread(img)
#   gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#   gray_image = cv2.resize(gray_image,(100, 120))
#   return gray_image

# %%
# loaded_img = []
# image_counts = []
# for path in dataset_path:
#   # Get all image in every ordner
#   gesture_path = os.path.join(path, '*')
#   gest_path = glob.glob(gesture_path)
#   image_counts.append(len(gest_path))
#   for i in range(0, len(gest_path)):
#     preprocessed_img = preprocessing(gest_path[i])
#     loaded_img.append(preprocessed_img)

# print(f"Es gibt insgesamt: {len(loaded_img)} Bilder")

# %%
# # Visualisation of the distribution in each class
# plt.figure(figsize=(10, 6))
# plt.bar(labels, image_counts)
# plt.xlabel('Klasse')
# plt.ylabel('Anzahl der Bilder')
# plt.title('Anzahl der Bilder je Klasse')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
